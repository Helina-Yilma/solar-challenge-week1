# %% [markdown]
# ## Load Data

# %%
import sys
import os

# Add project root to path
sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# ## EDA
# ---

# %%
from src.cleaner import Cleaner
from src.visualizer import plot_time_series, plot_corr_heatmap
from src.analyzer import monthly_trends, hourly_trends

# Load data
df = pd.read_csv("../data/benin-malanville.csv")

# Clean
cleaner = Cleaner(df)
df = cleaner.convert_types()
#df = cleaner.remove_outliers(['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust'])

# EDA
plot_time_series(df)
plot_corr_heatmap(df, ['GHI', 'DNI', 'DHI', 'TModA', 'TModB'])
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
