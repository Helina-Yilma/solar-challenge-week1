# %% [markdown]
# ## Load Data

# %%
import sys
import os

# Add project root to path
sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# ## EDA
# ---

# %%
from src.cleaner import Cleaner
from src.visualizer import plot_time_series, plot_corr_heatmap,  plot_monthly_metrics, plot_daily_trends
from src.analyzer import monthly_trends, hourly_trends

# Load data
df = pd.read_csv("../data/benin-malanville.csv")

# Clean
cleaner = Cleaner(df)
df = cleaner.convert_types()
#df = cleaner.remove_outliers(['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust'])

# EDA
plot_time_series(df)
plot_corr_heatmap(df, ['GHI', 'DNI', 'DHI', 'TModA', 'TModB'])
plot_monthly_metrics(df)
plot_daily_trends(df, date_col='Date')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[44], line 2
#       1 from src.cleaner import Cleaner
# ----> 2 from src.visualizer import plot_time_series, plot_corr_heatmap,  plot_monthly_metrics, plot_daily_trends
#       3 from src.analyzer import monthly_trends, hourly_trends
#       5 # Load data
#
# ImportError: cannot import name 'plot_monthly_metrics' from 'src.visualizer' (C:\Users\Lenovo\Documents\KAIM\Week0\Solar challenge\solar-challenge-week1\src\visualizer.py)
